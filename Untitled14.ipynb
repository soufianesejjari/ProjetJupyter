# %%
import csv

f = open('C:/Users/pc/Downloads/titanic.csv')
db=csv.reader(f)
listX=[]
listY=[]

# %%
head=db[0]
data=db[:1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7364/1329201443.py in <module>
# ----> 1 head=db[0]
#       2 data=db[:1]
#
# TypeError: '_csv.reader' object is not subscriptable

# %%
import csv

with open('coors.csv', mode='r') as infile:
    reader = csv.reader(infile)
    with open('coors_new.csv', mode='w') as outfile:
        writer = csv.writer(outfile)
        mydict = {rows[0]:rows[1] for rows in reader}

# %%
with open('C:/Users/pc/Downloads/Compressed/archive/exams.csv') as f:
    csv_list = [[val.strip() for val in r.split(",")] for r in f.readlines()]

(_, *header), *data = csv_list
csv_dict = {}
for row in data:
    key, *values = row   
    csv_dict[key] = {key: value for key, value in zip(header, values)}

# %%
csv_dict
# Out:
# {'"male"': {'"race/ethnicity"': '"group A"',
#   '"parental level of education"': '"some college"',
#   '"lunch"': '"standard"',
#   '"test preparation course"': '"completed"',
#   '"math score"': '"65"',
#   '"reading score"': '"60"',
#   '"writing score"': '"62"'},
#  '"female"': {'"race/ethnicity"': '"group C"',
#   '"parental level of education"': '"some college"',
#   '"lunch"': '"standard"',
#   '"test preparation course"': '"none"',
#   '"math score"': '"73"',
#   '"reading score"': '"74"',
#   '"writing score"': '"82"'}}

# %%
for l in len(db:
    for i in range(len(l)):
        
    x=l[0]
    y=l[1]
    listX.append(x)
    listY.append(y)

# %%
mydict = {y[0]: y[1] for y in [x.split(",") for x in open('C:/Users/pc/Downloads/Compressed/archive/exams.csv').read().split('\n') if x]}

# %%
import csv
reader = csv.reader(open('C:/Users/pc/Downloads/Compressed/archive/exams.csv'))

result = {}
for row in reader:
    key = row[0]
    if key in result:
        # implement your duplicate row handling here
        pass
    result[key] = row[1:]
print(result)
# Out:
# {'gender': ['race/ethnicity', 'parental level of education', 'lunch', 'test preparation course', 'math score', 'reading score', 'writing score'], 'male': ['group A', 'some college', 'standard', 'completed', '65', '60', '62'], 'female': ['group C', 'some college', 'standard', 'none', '73', '74', '82']}

# %%
import csv
import matplotlib.pyplot as plt

reader = csv.DictReader(open('C:/Users/pc/Downloads/Compressed/archive/exams.csv'))

result = {}
for row in reader:
    for column, value in row.items():  # consider .iteritems() for Python 2
        result.setdefault(column, []).append(value)
print(result)
# Out:
# {'gender': ['male', 'female', 'male', 'male', 'male', 'female', 'female', 'male', 'male', 'male', 'male', 'female', 'male', 'male', 'male', 'male', 'male', 'female', 'female', 'male', 'female', 'male', 'male', 'female', 'male', 'male', 'female', 'male', 'female', 'female', 'male', 'male', 'male', 'female', 'female', 'female', 'female', 'male', 'female', 'male', 'female', 'male', 'male', 'female', 'male', 'male', 'male', 'female', 'female', 'male', 'male', 'female', 'female', 'female', 'male', 'female', 'female', 'male', 'female', 'male', 'male', 'female', 'male', 'male', 'male', 'female', 'male', 'female', 'male', 'female', 'female', 'male', 'female', 'female', 'male', 'female', 'female', 'female', 'male', 'male', 'female', 'female', 'female', 'male', 'female', 'female', 'female', 'male', 'female', 'male', 'male', 'male', 'female', 'male', 'male', 'female', 'female', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'female', 'female', 'male', 'male', 'male', 'male', 'female', 
# ...

# %%
print(keysList)
keysList=['gender']
keysList = list(result.keys())
# Out:
# ['gender']

# %%
z={k:v for k,v in zip(result["math score"],result["gender"]) if int(k)>54 and v=="male" }
print(z)
# Out:
# {'67': 'male', '59': 'male', '77': 'male', '78': 'male', '93': 'male', '63': 'male', '99': 'male', '74': 'male', '81': 'male', '69': 'male', '58': 'male', '71': 'male', '87': 'male', '98': 'male', '100': 'male', '60': 'male', '64': 'male', '65': 'male', '57': 'male', '88': 'male', '68': 'male', '76': 'male', '83': 'male', '79': 'male', '97': 'male', '72': 'male', '94': 'male', '75': 'male', '66': 'male', '82': 'male', '56': 'male', '92': 'male', '62': 'male', '55': 'male', '73': 'male', '80': 'male', '84': 'male', '89': 'male', '85': 'male', '61': 'male', '90': 'male', '86': 'male', '96': 'male', '70': 'male', '91': 'male', '95': 'male'}

# %% [markdown]
# # nombres des variabes par attribut

# %%
for l in keysList:
    re = {i:result[l].count(i) for i in result[l] }
    if (len(re)<30):

        print(l," ",len(re), re)
        width = 0.7
        c = ['red', 'yellow', 'black', 'blue', 'orange','pink']
        plt.bar(re.keys(), re.values(), width, color=c)
        plt.show()
    else:
        print(l," ",len(re), )
# Out:
# gender   2 {'male': 517, 'female': 483}
# race/ethnicity   5 {'group A': 79, 'group D': 262, 'group E': 131, 'group B': 205, 'group C': 323}
# parental level of education   6 {'high school': 202, 'some high school': 191, 'some college': 222, "associate's degree": 203, "bachelor's degree": 112, "master's degree": 70}
# lunch   2 {'standard': 652, 'free/reduced': 348}
# test preparation course   2 {'completed': 335, 'none': 665}
# math score   77
# reading score   73
# writing score   76

# %%
import matplotlib.pyplot as plt
keysList=["gender"]
for l in keysList:
    re = {i:result[l].count(i) for i in result[l] }
    if (len(re)<30):
            width = 0.7
            plt.bar(re.keys(), re.values(), width, color='b')

# %%
for l in keysList:
    
    re = {i:result[l].count(i) for i in result[l] }
    if (len(re)<30):

        print(l," ",len(re), re)
        width = 0.7
        c = ['red', 'yellow', 'black', 'blue', 'orange','pink']
        
   
    else:
        print(l," ",len(re), )

# %%
result["math score"]
plt.plot(result["math score"],result["gender"])
plt.show()

# %%
re = {i:result["math score"].count(i) for i in result["math score"] }
print(re.values())
# Out:
# dict_values([1000])

# %%
result["math score"]=list(map(lambda x :"Not admis" if int(x)<50  else  "admis" ,result["math score"]))


re = {i:rrr.count(i) for i in result["math score"] }



#result["math score"]=mathscore

print(re)
# Out:
# {'admis': 1000, 'Not admis': 0}

# %%
femme=list(filter(lambda x: x>10,list(result['gender'],result['math score'])))

femme=list(map( lambda x,y: x>10 and y="male",result['gender'],result['math score']))
# Out:
#   File "C:\Users\pc\AppData\Local\Temp/ipykernel_7364/2043483309.py", line 3
#     femme=list(map( lambda x,y: x>10 and y="male",result['gender'],result['math score']))
#                     ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
for row in result: 
    print(row)
# Out:
# gender
# race/ethnicity
# parental level of education
# lunch
# test preparation course
# math score
# reading score
# writing score

# %%
x=[]
y=[]
for row in result: 
        x.append([result["gender"]])

        y.append([result["math score"]])

  
print(x)
print(y)
plt.plot(x, y, color = 'g', linestyle = 'dashed', 

         marker = 'o',label = "Weather Data") 

  

plt.xticks(rotation = 25) 

plt.xlabel('Dates') 

plt.ylabel('Temperature(°C)') 

plt.title('Weather Report', fontsize = 20) 
plt.grid() 
plt.legend() 
plt.show()
# Out:
# [[['male', 'female', 'male', 'male', 'male', 'female', 'female', 'male', 'male', 'male', 'male', 'female', 'male', 'male', 'male', 'male', 'male', 'female', 'female', 'male', 'female', 'male', 'male', 'female', 'male', 'male', 'female', 'male', 'female', 'female', 'male', 'male', 'male', 'female', 'female', 'female', 'female', 'male', 'female', 'male', 'female', 'male', 'male', 'female', 'male', 'male', 'male', 'female', 'female', 'male', 'male', 'female', 'female', 'female', 'male', 'female', 'female', 'male', 'female', 'male', 'male', 'female', 'male', 'male', 'male', 'female', 'male', 'female', 'male', 'female', 'female', 'male', 'female', 'female', 'male', 'female', 'female', 'female', 'male', 'male', 'female', 'female', 'female', 'male', 'female', 'female', 'female', 'male', 'female', 'male', 'male', 'male', 'female', 'male', 'male', 'female', 'female', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'female', 'female', 'male', 'male', 'male', 'male', 'female', 'female',
# ...

# %%
result[]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7364/223460175.py in <module>
# ----> 1 result[0]
#
# KeyError: 0

# %%
res = {i:result["gender"].count(i) for i in result["gender"]}

print(res)
# Out:
# {'male': 517, 'female': 483}

# %%
def count_val(liste):
    return print({i:list().count(i) for i in liste})

# %%
for l in result:
    count_val(l)
# Out:
# {'g': 0, 'e': 0, 'n': 0, 'd': 0, 'r': 0}
# {'r': 0, 'a': 0, 'c': 0, 'e': 0, '/': 0, 't': 0, 'h': 0, 'n': 0, 'i': 0, 'y': 0}
# {'p': 0, 'a': 0, 'r': 0, 'e': 0, 'n': 0, 't': 0, 'l': 0, ' ': 0, 'v': 0, 'o': 0, 'f': 0, 'd': 0, 'u': 0, 'c': 0, 'i': 0}
# {'l': 0, 'u': 0, 'n': 0, 'c': 0, 'h': 0}
# {'t': 0, 'e': 0, 's': 0, ' ': 0, 'p': 0, 'r': 0, 'a': 0, 'i': 0, 'o': 0, 'n': 0, 'c': 0, 'u': 0}
# {'m': 0, 'a': 0, 't': 0, 'h': 0, ' ': 0, 's': 0, 'c': 0, 'o': 0, 'r': 0, 'e': 0}
# {'r': 0, 'e': 0, 'a': 0, 'd': 0, 'i': 0, 'n': 0, 'g': 0, ' ': 0, 's': 0, 'c': 0, 'o': 0}
# {'w': 0, 'r': 0, 'i': 0, 't': 0, 'n': 0, 'g': 0, ' ': 0, 's': 0, 'c': 0, 'o': 0, 'e': 0}

# %%
mydict{"gender"}
# Out:
#   File "C:\Users\pc\AppData\Local\Temp/ipykernel_7364/2113515005.py", line 1
#     mydict{"gender"}
#           ^
# SyntaxError: invalid syntax
